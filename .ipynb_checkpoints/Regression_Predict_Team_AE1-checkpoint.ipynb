# %% [markdown]
# # 1. Introduction

# %% [markdown]
# This notebook forms part of the Advanced Regression Predict deliverables which requires the team to use the various data science aspects learnt from the EGAD framework with the knowledge gained from the Regression Course Sprint. With this context, EDSA is challenging us to construct a regression algorithm, capable of accurately predicting how much a kilogram of Golden Delicious Apples will cost, given certain parameters. The Predict consists of three main tasks each containing subtasks:
#
# ### 1) Compete in a Hackathon Challenge on Kaggle:
# - Train a regression model to predict the average price per kilogram for Golden Delicious Apples from explanatory features.
# - Create this notebook and collaborate on GitHub - develop, train and validate the regression model to submit the output on Kaggle
#
# ### 2) Build a Web-Based API for the Model:
# - ?
#
# ### 3) Communicate Findings:
# - ?
#
#
# The evaluation metric for this competition is Root Mean Square Error. Root Mean Square Error  is commonly used in regression analysis and forecasting, and measures the standard deviation of the residuals arising between predicted and actual observed values for a modelling process. For our task of predicting the average price per kilogram of Golden Delicous Apples, the formula is given by:
#
# $$ RMSE = \sqrt{\frac{1}{|\hat{R}|}\Sigma_{\hat{r}_{i}\in\hat{R}}^{n}{({r_i -\hat{r}_i})^2}}$$
#
# Where \\( \hat{R} \\) is the total number of predictions generated for the average price per kilogram of Golden Delicous Apples, with \\( r_{i} \\) and \\( \hat{r}_{i} \\) being the true and predicted prices.
#
#
# Submission Format
# The submission file should contain two columns: Index and Price. 'Index' is given in the test file. 'Price' is the predicted average price per kilogram of Golden Delicious Apples
#
#  <br> The file should contain a header and have the following format:
#
# Index, Price
#
# 1, 13.94

# %% [markdown]
# ## 1.1 Team Members

# %% [markdown]
# ### The team members for group **Regression_AE1_DSFT** consists of:
# - Mmajoala Carol Lamola - Team member
# - Leon Smith - Team coordinator
# - Katleho Moketo - Team member
# - Kwanda Silekwa - Team member
# - Sifiso Ndiza - Team member
# - Ali Elimam - Team supervisor

# %% [markdown]
# ## 1.2 Problem Statement

# %% [markdown]
# The challenge is to construct a regression algorithm, capable of accurately predicting how much a kilogram of
# Golden Delicious Apples will cost, given certain parameters.

# %% [markdown]
# # 2. Load Data

# %% [markdown]
# ## 2.1 Import Libraries
# Import all the libraries required.

# %%
# Other imports to follow as required
import numpy as np # used for mathematical operations
import pandas as pd
import matplotlib.pyplot as plt # for plotting data
import seaborn as sns # for plotting data
from statsmodels.graphics.correlation import plot_corr
from matplotlib import rc

# %%
# Set display settings for dataframes
pd.set_option('display.max_rows', 2000)
pd.set_option('display.max_columns', 2000)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 2.2 Read csv Files
# The training and testing data, `trains_set` and `test_set` respectively are loaded from GitHub repo as Pandas DataFrames. This dataset consists of over 60 000 sales made by Durban Fresh Produce Market and includes the average price per kg for commodities with describing paramaters.

# %%
# Read data in from donwloaded csv files
df_train = pd.read_csv("data/df - train_set.csv")
df_test = pd.read_csv("data/df - test_set.csv", index_col=0)
df_sample = pd.read_csv("data/sample_submission.csv")

# %% [markdown]
# ## 2.3 Inspect Dataframes

# %%
df_train.head()
# Out:
#             Province Container Size_Grade  Weight_Kg             Commodities  \
# 0               CAPE     EC120         1L       12.0      APPLE GRANNY SMITH
# 1               CAPE     M4183         1L       18.3  APPLE GOLDEN DELICIOUS
# 2            GAUTENG     AT200         1L       20.0       AVOCADO PINKERTON
# 3          TRANSVAAL     BJ090         1L        9.0      TOMATOES-LONG LIFE
# 4  WESTERN FREESTATE     PP100         1R       10.0   POTATO SIFRA (WASHED)
#
#          Date  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 0  2020-03-10      108.0       112.0       3236.0              29
# 1  2020-09-09      150.0       170.0      51710.0             332
# 2  2020-05-05       70.0        80.0       4860.0              66
# 3  2020-01-20       60.0        60.0        600.0              10
# 4  2020-07-14       40.0        45.0      41530.0             927
#
#    Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg
# 0          348.0              0              9.30
# 1         6075.6            822              8.51
# 2         1320.0             50              3.68
# 3           90.0              0              6.67
# 4         9270.0            393              4.48

# %%
df_train.shape
# Out:
# (64376, 13)

# %%
df_test.head()
# Out:
#                    Province Container Size_Grade  Weight_Kg  \
# Index
# 1      W.CAPE-BERGRIVER ETC     EC120         1M       12.0
# 2      W.CAPE-BERGRIVER ETC     M4183         1X       18.3
# 3      W.CAPE-BERGRIVER ETC     EC120         1S       12.0
# 4      W.CAPE-BERGRIVER ETC     M4183         1M       18.3
# 5      W.CAPE-BERGRIVER ETC     M4183         1L       18.3
#
#                   Commodities        Date  Low_Price  High_Price  Sales_Total  \
# Index
# 1      APPLE GOLDEN DELICIOUS  2020-07-09      128.0       136.0       5008.0
# 2      APPLE GOLDEN DELICIOUS  2020-01-20      220.0       220.0       1760.0
# 3      APPLE GOLDEN DELICIOUS  2020-08-19      120.0       120.0        720.0
# 4      APPLE GOLDEN DELICIOUS  2020-05-06      160.0       160.0        160.0
# 5      APPLE GOLDEN DELICIOUS  2020-05-04      140.0       160.0      14140.0
#
#        Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand
# Index
# 1                  38          456.0              0
# 2                   8          146.4              2
# 3                   6           72.0             45
# 4                   1           18.3              8
# 5                 100         1830.0             19

# %%
df_test.shape
# Out:
# (685, 12)

# %% [markdown]
# The data fields for the loaded csv files are described as follows:
# - Province - Which province the produce was grown
# - Container - The code for the type of container
# - Size_Grade - The class of the produce according to their quality
# - Weight_Kg - The total weight in kilograms
# - Commodities - The type of produce, e.g. Golden Delicious Apples
# - Date - The date of the sale
# - Sales_Total - The total sales price
# - Total_Qty_Sold - The number of produce sold
# - Total_Kg_Sold - The total weight of the produce sold in kilograms
# - Stock_On_Hand - The amount of produce the store has

# %% [markdown]
# # 3. Initial Cleaning
# An initial cleaning step to be able to perform valuable EDA.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64376 entries, 0 to 64375
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Province          64376 non-null  object
#  1   Container         64376 non-null  object
#  2   Size_Grade        64376 non-null  object
#  3   Weight_Kg         64376 non-null  float64
#  4   Commodities       64376 non-null  object
#  5   Date              64376 non-null  object
#  6   Low_Price         64376 non-null  float64
#  7   High_Price        64376 non-null  float64
#  8   Sales_Total       64376 non-null  float64
#  9   Total_Qty_Sold    64376 non-null  int64
#  10  Total_Kg_Sold     64376 non-null  float64
#  11  Stock_On_Hand     64376 non-null  int64
#  12  avg_price_per_kg  64376 non-null  float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 6.4+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 1 to 685
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        685 non-null    object
#  1   Container       685 non-null    object
#  2   Size_Grade      685 non-null    object
#  3   Weight_Kg       685 non-null    float64
#  4   Commodities     685 non-null    object
#  5   Date            685 non-null    object
#  6   Low_Price       685 non-null    float64
#  7   High_Price      685 non-null    float64
#  8   Sales_Total     685 non-null    float64
#  9   Total_Qty_Sold  685 non-null    int64
#  10  Total_Kg_Sold   685 non-null    float64
#  11  Stock_On_Hand   685 non-null    int64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 69.6+ KB

# %% [markdown]
# ### Keep only relevant data
# The aim is to predict the price/kg of `Apple Golden Delicious`. The unseen data to be submitted also only has this commodity category. The training data is then filtered for only the "Apple Golden Delicious" commodity/produce category.

# %%
df_test.Commodities.unique()
# Out:
# array(['APPLE GOLDEN DELICIOUS'], dtype=object)

# %%
df_test.Commodities.value_counts()
# Out:
# APPLE GOLDEN DELICIOUS    685
# Name: Commodities, dtype: int64

# %%
df_train.Commodities.nunique()
# Out:
# 270

# %%
df_train.Commodities.value_counts().head(10)
# Out:
# POTATO (WASHED) MONDIAL    4134
# TOMATOES-LONG LIFE         3849
# ONIONS BROWN               3420
# POTATO SIFRA (WASHED)      3092
# ONIONS MILD                2714
# LEMON                      2106
# POTATO LANORMA (WASHED)    1979
# APPLE GOLDEN DELICIOUS     1952
# PEAR PACKHAMS TRIUMPH      1921
# CUCUMBERS ENGLISH          1704
# Name: Commodities, dtype: int64

# %%
df_train = df_train[df_train["Commodities"] == "APPLE GOLDEN DELICIOUS"]

# %%
df_train.Commodities.unique()
# Out:
# array(['APPLE GOLDEN DELICIOUS'], dtype=object)

# %%
df_train.Commodities.value_counts()
# Out:
# APPLE GOLDEN DELICIOUS    1952
# Name: Commodities, dtype: int64

# %% [markdown]
# ## 3.1 Data types
# From the above analysis it shows that the `Date` coloumn is an object data type and should be in the `datetime` data type format.

# %%
df_train['Date'] = pd.to_datetime(df_train['Date'])
df_test['Date'] = pd.to_datetime(df_test['Date'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1952 entries, 1 to 64310
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Province          1952 non-null   object
#  1   Container         1952 non-null   object
#  2   Size_Grade        1952 non-null   object
#  3   Weight_Kg         1952 non-null   float64
#  4   Commodities       1952 non-null   object
#  5   Date              1952 non-null   datetime64[ns]
#  6   Low_Price         1952 non-null   float64
#  7   High_Price        1952 non-null   float64
#  8   Sales_Total       1952 non-null   float64
#  9   Total_Qty_Sold    1952 non-null   int64
#  10  Total_Kg_Sold     1952 non-null   float64
#  11  Stock_On_Hand     1952 non-null   int64
#  12  avg_price_per_kg  1952 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 213.5+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 1 to 685
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        685 non-null    object
#  1   Container       685 non-null    object
#  2   Size_Grade      685 non-null    object
#  3   Weight_Kg       685 non-null    float64
#  4   Commodities     685 non-null    object
#  5   Date            685 non-null    datetime64[ns]
#  6   Low_Price       685 non-null    float64
#  7   High_Price      685 non-null    float64
#  8   Sales_Total     685 non-null    float64
#  9   Total_Qty_Sold  685 non-null    int64
#  10  Total_Kg_Sold   685 non-null    float64
#  11  Stock_On_Hand   685 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 69.6+ KB

# %% [markdown]
# ## 3.2 Missing Data
# To check if any of the dataframe columns contain missing data the following code and functions are used to identify missing data.

# %%
# Function to determine number of missing entries.

def total_missing(df,column_name):
    # Counts total number of missing entries per column given.
    miss_entr = df[column_name].isnull().sum()
    return miss_entr

# %%
total_missing(df_train, df_train.columns)
# Out:
# Province            0
# Container           0
# Size_Grade          0
# Weight_Kg           0
# Commodities         0
# Date                0
# Low_Price           0
# High_Price          0
# Sales_Total         0
# Total_Qty_Sold      0
# Total_Kg_Sold       0
# Stock_On_Hand       0
# avg_price_per_kg    0
# dtype: int64

# %%
total_missing(df_test, df_test.columns)
# Out:
# Province          0
# Container         0
# Size_Grade        0
# Weight_Kg         0
# Commodities       0
# Date              0
# Low_Price         0
# High_Price        0
# Sales_Total       0
# Total_Qty_Sold    0
# Total_Kg_Sold     0
# Stock_On_Hand     0
# dtype: int64

# %% [markdown]
# The above confirms that there are no null values in the data.

# %% [markdown]
# ## 3.3 Unique Data

# %%
df_train.nunique()
# Out:
# Province               7
# Container             11
# Size_Grade            10
# Weight_Kg              9
# Commodities            1
# Date                 147
# Low_Price             94
# High_Price            88
# Sales_Total         1324
# Total_Qty_Sold       505
# Total_Kg_Sold        850
# Stock_On_Hand        735
# avg_price_per_kg     601
# dtype: int64

# %%
df_test.nunique()
# Out:
# Province            7
# Container          11
# Size_Grade         10
# Weight_Kg           9
# Commodities         1
# Date              144
# Low_Price          70
# High_Price         65
# Sales_Total       569
# Total_Qty_Sold    285
# Total_Kg_Sold     426
# Stock_On_Hand     393
# dtype: int64

# %% [markdown]
# # 4. Exploratory Data Analysis
# This phase is extremely important. It helps to understand patterns in the data, pinpoint any outliers and indicate relationships between variables. This phase includes descriptive statistics and data visualisations.
# <br>
#
# The data will be used to determine the average price per kilogram for Golden Delicious Apples from explanatory features.

# %% [markdown]
# ## 4.1 Basic Analysis
# Some basic analysis is performed on the data to better understand what data will be delt with.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1952 entries, 1 to 64310
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Province          1952 non-null   object
#  1   Container         1952 non-null   object
#  2   Size_Grade        1952 non-null   object
#  3   Weight_Kg         1952 non-null   float64
#  4   Commodities       1952 non-null   object
#  5   Date              1952 non-null   datetime64[ns]
#  6   Low_Price         1952 non-null   float64
#  7   High_Price        1952 non-null   float64
#  8   Sales_Total       1952 non-null   float64
#  9   Total_Qty_Sold    1952 non-null   int64
#  10  Total_Kg_Sold     1952 non-null   float64
#  11  Stock_On_Hand     1952 non-null   int64
#  12  avg_price_per_kg  1952 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 213.5+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 685 entries, 1 to 685
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province        685 non-null    object
#  1   Container       685 non-null    object
#  2   Size_Grade      685 non-null    object
#  3   Weight_Kg       685 non-null    float64
#  4   Commodities     685 non-null    object
#  5   Date            685 non-null    datetime64[ns]
#  6   Low_Price       685 non-null    float64
#  7   High_Price      685 non-null    float64
#  8   Sales_Total     685 non-null    float64
#  9   Total_Qty_Sold  685 non-null    int64
#  10  Total_Kg_Sold   685 non-null    float64
#  11  Stock_On_Hand   685 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(4)
# memory usage: 69.6+ KB

# %%
df_train.shape
# Out:
# (1952, 13)

# %%
df_test.shape
# Out:
# (685, 12)

# %% [markdown]
# The variables' (predictors / features) datatypes are inspected and grouped accordingly as either a categorical, numerical or interval feature.
# #### Categorical features:
#     Province, Container, Size_Grade, Commodities
#
# ####  Numerical features:
#     Weight_Kg, Low_Price, High_Price, Sales_Total, Total_Qty_Sold, Total_Kg_Sold, Stock_On_Hand
# #### Interval features:
#     Date

# %%
categorical_cols = ["Province", "Container", "Size_Grade"]
numerical_cols = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]
date_cols = ["Date"]
label = ["avg_price_per_kg"]

# %%
df_train.columns
# Out:
# Index(['Province', 'Container', 'Size_Grade', 'Weight_Kg', 'Commodities',
#        'Date', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold',
#        'Total_Kg_Sold', 'Stock_On_Hand', 'avg_price_per_kg'],
#       dtype='object')

# %% [markdown]
# The shape commands indicates that the `df_train` dataframe has 1952 observations and 13 features which includes the 1 response variable to be predicted.
# <br>
# The `df_test` dataframe has 685 observations and 12 features - the model will use the `df_test` set to predict the response variable during the testing phase and is therefore not included in the dataframe. It will be used to evaluate how well the model predicts in the test phase.

# %% [markdown]
# ## 4.2 Univartiate Analysis - Summary Statistics / Non-graphical
# The following descriptive statistics for each numerical feature is shown. It includes the 5 number summary as indicated below:

# %%
df_train.describe().T
# Out:
#                    count          mean           std   min      25%      50%  \
# Weight_Kg         1952.0     40.460912     99.655169  3.00     9.00    12.00
# Low_Price         1952.0    174.307377    373.553578  2.00    50.00    80.00
# High_Price        1952.0    215.648053    433.546159  5.00    60.00   108.00
# Sales_Total       1952.0  20053.533811  39005.069445  5.00  1325.00  5495.00
# Total_Qty_Sold    1952.0    174.510758    308.810797  1.00    12.00    64.00
# Total_Kg_Sold     1952.0   2960.176332   6097.416527  3.00   219.60   853.50
# Stock_On_Hand     1952.0    408.393955    724.450582  0.00     9.00   126.50
# avg_price_per_kg  1952.0      6.778893      2.248744  0.25     5.46     6.67
#
#                         75%        max
# Weight_Kg            18.300     400.00
# Low_Price           127.250    2300.00
# High_Price          160.000    3300.00
# Sales_Total       21082.500  369464.00
# Total_Qty_Sold      200.000    4237.00
# Total_Kg_Sold      3093.525   74000.00
# Stock_On_Hand       468.000    6400.00
# avg_price_per_kg      8.280      21.24

# %%
df_test.describe().T
# Out:
#                 count          mean           std   min     25%     50%  \
# Weight_Kg       685.0     34.142482     87.575995   3.0     9.0    12.0
# Low_Price       685.0    164.202891    355.167319  10.0    50.0    80.0
# High_Price      685.0    195.590073    389.109476  10.0    64.0   112.0
# Sales_Total     685.0  18788.111212  33951.586813  10.0  1300.0  5520.0
# Total_Qty_Sold  685.0    174.883212    299.351142   1.0    13.0    62.0
# Total_Kg_Sold   685.0   2725.402336   5059.123311   6.3   204.0   860.1
# Stock_On_Hand   685.0    439.245255    715.985761   0.0    20.0   153.0
#
#                     75%       max
# Weight_Kg          18.3     400.0
# Low_Price         128.0    2400.0
# High_Price        160.0    2400.0
# Sales_Total     21176.0  308010.0
# Total_Qty_Sold    200.0    2774.0
# Total_Kg_Sold    3033.0   47200.0
# Stock_On_Hand     516.0    6827.0

# %%
df_train["Province"].value_counts()
# Out:
# CAPE                    1045
# W.CAPE-BERGRIVER ETC     440
# EASTERN CAPE             206
# WEST COAST               126
# NATAL                    111
# TRANSVAAL                 15
# ORANGE FREE STATE          9
# Name: Province, dtype: int64

# %%
df_train["Container"].value_counts()
# Out:
# M4183    588
# JE090    565
# EC120    448
# IA400    139
# JG110     85
# EF120     74
# AC030     31
# M6125     10
# DT063      6
# M9125      3
# EG140      3
# Name: Container, dtype: int64

# %%
df_train["Size_Grade"].value_counts()
# Out:
# 1S    532
# 1M    319
# 2S    308
# 2M    232
# 1L    225
# 1X    171
# 2L    120
# 2X     26
# 2U     17
# 1U      2
# Name: Size_Grade, dtype: int64

# %% [markdown]
# Based on the mean and standard deviation above for the numerical predictor variables some scaling will be required.
# <br> Also the categorical features have some categories that do not occur often and some that make up most of the data observations.

# %% [markdown]
# #### Kurtosis and Skew
#
# In addition, both kurtosis and skew are is checked for more insights. Kurtosis is the measure of outliers present in the data and skew will indicate how symmetrical the data is.

# %%
# Skewness and Kurtosis for the predictor variable avg_price_per_kg

print("Skewness: %f" %df_train["avg_price_per_kg"].skew())
print("Kurtosis: %f" %df_train["avg_price_per_kg"].kurt())
# Out:
# Skewness: 0.082452
# Kurtosis: 1.042921

# %%
df_train.skew()
# Out:
# Weight_Kg           3.328254
# Low_Price           4.222672
# High_Price          3.828819
# Sales_Total         4.250317
# Total_Qty_Sold      4.445169
# Total_Kg_Sold       5.529586
# Stock_On_Hand       3.391815
# avg_price_per_kg    0.082452
# dtype: float64

# %%
df_train.kurtosis()
# Out:
# Weight_Kg            9.109698
# Low_Price           17.073369
# High_Price          13.630768
# Sales_Total         24.200524
# Total_Qty_Sold      32.338123
# Total_Kg_Sold       45.153801
# Stock_On_Hand       14.671224
# avg_price_per_kg     1.042921
# dtype: float64

# %% [markdown]
# Try to improve the Kurtosis and Skewness - to minimise the effect of outliers.

# %%
categorical_cols = ["Province", "Container", "Size_Grade"]
numerical_cols = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]df_train[df_train["avg_price_per_kg"] < 15]["avg_price_per_kg"].kurtosis()
# Out:
# 0.23553902592201315

# %%
numeric = ["Weight_Kg",
            "Low_Price",
            "High_Price",
            "Sales_Total",
            "Total_Qty_Sold",           
            "Total_Kg_Sold",
            "Stock_On_Hand",
            "avg_price_per_kg"]

# %%
np.log(df_train[numeric]).fillna(0).replace(-np.inf, 0).replace(np.inf, 0).skew()
# Out:
# Weight_Kg           2.624779
# Low_Price           1.141070
# High_Price          1.089270
# Sales_Total        -0.482850
# Total_Qty_Sold     -0.362500
# Total_Kg_Sold      -0.411865
# Stock_On_Hand      -0.511006
# avg_price_per_kg   -1.957967
# dtype: float64

# %%
df_train[df_train["avg_price_per_kg"] < 15]["avg_price_per_kg"].skew()
# Out:
# -0.0695503360275071

# %%
np.log(df_train[numeric]).fillna(0).replace(-np.inf, 0).replace(np.inf, 0).kurtosis()
# Out:
# Weight_Kg           6.586745
# Low_Price           3.507276
# High_Price          3.291294
# Sales_Total        -0.018742
# Total_Qty_Sold     -0.653029
# Total_Kg_Sold      -0.270050
# Stock_On_Hand      -1.030570
# avg_price_per_kg    6.789581
# dtype: float64

# %% [markdown]
# ## 4.3 Univartiate Analysis - Visual Representations
# The distribution for the numerical feautres will be plotted against the predictor variable to determine if there are any strong correlations.
# <br>For the categorical features a histogram and density plot will be used to visualise them.

# %%
df_train["avg_price_per_kg"].describe()
# Out:
# count    1952.000000
# mean        6.778893
# std         2.248744
# min         0.250000
# 25%         5.460000
# 50%         6.670000
# 75%         8.280000
# max        21.240000
# Name: avg_price_per_kg, dtype: float64

# %%
fig = plt.figure(figsize=(9, 7))
sns.histplot(df_train["avg_price_per_kg"], stat="density", kde=True)
# Out:
# <AxesSubplot:xlabel='avg_price_per_kg', ylabel='Density'>

# %% [markdown]
# From the graph and statistic values, the response variabel "avg_price_per_kg" has acceptable summary statistic values, skewness and kurtosis. It can be assumed then that it is noramlly distributed. There are some outlier values and positive skewness.

# %% [markdown]
# ### Analyse Time Intervals

# %% [markdown]
# Some feature engineering on the date variable to get different date formats.

# %%
df_train["quarter"] = pd.PeriodIndex(df_train["Date"], freq="Q")
df_train["year_month"] = pd.PeriodIndex(df_train["Date"], freq="M")
df_train["month"] = df_train["Date"].dt.month

# %%
def get_season(m):
    """
    Extract the seasons from the date value.
    """
    if m in [12,1,2]:
        return "summer"
    if m in [3,4,5]:
        return "autumn"
    if m in [6,7,8]:
        return "winter"
    return "spring"

# %%
df_train["season"] = df_train["month"].apply(get_season)

# %%
df_train.sort_values("Date")[["Date", "quarter", "month", "season"]].head()
# Out:
#             Date quarter  month  season
# 32221 2019-12-11  2019Q4     12  summer
# 30171 2019-12-11  2019Q4     12  summer
# 53893 2019-12-11  2019Q4     12  summer
# 64177 2019-12-11  2019Q4     12  summer
# 35634 2019-12-11  2019Q4     12  summer

# %%
df_train["season"].value_counts()
# Out:
# winter    827
# autumn    605
# summer    352
# spring    168
# Name: season, dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1952 entries, 1 to 64310
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Province          1952 non-null   object
#  1   Container         1952 non-null   object
#  2   Size_Grade        1952 non-null   object
#  3   Weight_Kg         1952 non-null   float64
#  4   Commodities       1952 non-null   object
#  5   Date              1952 non-null   datetime64[ns]
#  6   Low_Price         1952 non-null   float64
#  7   High_Price        1952 non-null   float64
#  8   Sales_Total       1952 non-null   float64
#  9   Total_Qty_Sold    1952 non-null   int64
#  10  Total_Kg_Sold     1952 non-null   float64
#  11  Stock_On_Hand     1952 non-null   int64
#  12  avg_price_per_kg  1952 non-null   float64
#  13  quarter           1952 non-null   period[Q-DEC]
#  14  year_month        1952 non-null   period[M]
#  15  month             1952 non-null   int64
#  16  season            1952 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(5), period[M](1), period[Q-DEC](1)
# memory usage: 274.5+ KB

# %%
df_train.head()
# Out:
#                 Province Container Size_Grade  Weight_Kg  \
# 1                   CAPE     M4183         1L       18.3
# 7                   CAPE     JG110         2M       11.0
# 24  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 40                  CAPE     M4183         1S       18.3
# 69          EASTERN CAPE     IA400         1S      400.0
#
#                Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 1   APPLE GOLDEN DELICIOUS 2020-09-09      150.0       170.0      51710.0
# 7   APPLE GOLDEN DELICIOUS 2020-04-14       50.0        50.0      16000.0
# 24  APPLE GOLDEN DELICIOUS 2020-04-16       55.0        55.0        990.0
# 40  APPLE GOLDEN DELICIOUS 2020-05-04       80.0       120.0      32020.0
# 69  APPLE GOLDEN DELICIOUS 2020-09-28     1800.0      1800.0       1800.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg quarter  \
# 1              332         6075.6            822              8.51  2020Q3
# 7              320         3520.0              0              4.55  2020Q2
# 24              18          162.0           1506              6.11  2020Q2
# 40             388         7100.4            443              4.51  2020Q2
# 69               1          400.0              2              4.50  2020Q3
#
#    year_month  month  season
# 1     2020-09      9  spring
# 7     2020-04      4  autumn
# 24    2020-04      4  autumn
# 40    2020-05      5  autumn
# 69    2020-09      9  spring

# %%
fig = plt.figure(figsize=(15, 7))
ax = fig.gca()
x = df_train["Date"]
y = df_train["avg_price_per_kg"]
plt.title("Scatter plot of Avg Price over Time")
plt.xlabel("Date")
plt.ylabel("avg_price_per_kg")
plt.scatter(x, y)
plt.grid()
plt.show()

# %% [markdown]
# There are 2x outliers that are distinct - the above R15 and R20 observations.

# %%
temp = df_train[["High_Price", "Low_Price", "avg_price_per_kg"]]
temp.index = df_train["Date"]
temp.plot(figsize=(15, 7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data = temp["avg_price_per_kg"])
resampled = temp["avg_price_per_kg"].resample("M").mean()
sns.lineplot(data = resampled)
resampled = temp["avg_price_per_kg"].resample("Q").mean()
sns.lineplot(data = resampled)
plt.legend(labels=["per day", "monthly avg", "quarterly avg"])

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.boxplot(x = "year_month", y="avg_price_per_kg", data = df_train, order=sorted(df_train["year_month"].unique()))
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.boxplot(x = "quarter", y="avg_price_per_kg", data = df_train, order=sorted(df_train["quarter"].unique()))
# Out:
# <AxesSubplot:xlabel='quarter', ylabel='avg_price_per_kg'>

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.boxplot(x="season", y="avg_price_per_kg", data = df_train, order=["summer", "autumn", "winter", "spring"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='avg_price_per_kg'>

# %% [markdown]
# The obove confirms that the date of the observations has some influence on the price - the prices cahnge as the seasons change. This is linked with demand and supply of the apples.

# %% [markdown]
# ### Relationship with Numerical Variables

# %%
fig, axs = plt.subplots(2, 4, figsize = (20, 10))
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)
axs = axs.ravel()


numeric_col = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]

for index, column in enumerate(numeric_col):
    axs[index].set_title("{} vs. avg_price_per_kg".format(column), fontsize = 15)
    axs[index].scatter(x = df_train[column], y = df_train.avg_price_per_kg, color = "blue")
    axs[index].set_xlabel("{}".format(column), fontsize = 10)
    axs[index].set_ylabel("avg_price_per_kg")
    
fig.tight_layout(pad = 1)

# %%
# sns.lmplot('Low_Price', 'avg_price_per_kg', df_train, aspect=2)

# %%
# sns.lmplot('High_Price', 'avg_price_per_kg', df_train, aspect=2)

# %%
# sns.lmplot('Sales_Total', 'avg_price_per_kg', df_train, aspect=2)

# %%
# sns.lmplot('Total_Qty_Sold', 'avg_price_per_kg', df_train, aspect=2)

# %%
# sns.lmplot('Total_Kg_Sold', 'avg_price_per_kg', df_train, aspect=2)

# %%
# sns.lmplot('Stock_On_Hand', 'avg_price_per_kg', df_train, aspect=2)

# %%
df_train[numeric_col].hist(figsize = (20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'Weight_Kg'}>,
#         <AxesSubplot:title={'center':'Low_Price'}>,
#         <AxesSubplot:title={'center':'High_Price'}>],
#        [<AxesSubplot:title={'center':'Sales_Total'}>,
#         <AxesSubplot:title={'center':'Total_Qty_Sold'}>,
#         <AxesSubplot:title={'center':'Total_Kg_Sold'}>],
#        [<AxesSubplot:title={'center':'Stock_On_Hand'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
# For clarity the numeric_col variable defined and showed again.
numeric_col = numerical_cols
numeric_col
# Out:
# ['Weight_Kg',
#  'Low_Price',
#  'High_Price',
#  'Sales_Total',
#  'Total_Qty_Sold',
#  'Total_Kg_Sold',
#  'Stock_On_Hand']

# %%
fig, axs = plt.subplots(4, 2, figsize = (20, 20))
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)
axs = axs.ravel()


numeric_col = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]

for index, column in enumerate(numeric_col):
    axs[index].set_title("{} vs. avg_price_per_kg".format(column), fontsize = 15)
    sns.boxplot(x = column, data = df_train, ax=axs[index])
    axs[index].set_xlabel("{}".format(column), fontsize = 15)
    axs[index].set_ylabel("avg_price_per_kg", fontsize = 15)
    
fig.tight_layout(pad = 1)

# %%
# fig, axs = plt.subplots(4, 2, figsize = (20, 20))
# fig.subplots_adjust(hspace = 0.5, wspace = 0.5)
# axs = axs.ravel()


# numeric_col = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]

# for index, column in enumerate(numeric_col):
#     axs[index].set_title("{}".format(column), fontsize = 15)
#     sns.violinplot(x = column, data = df_train, ax=axs[index])
#     axs[index].set_xlabel("{}".format(column), fontsize = 10)
    
# fig.tight_layout(pad = 1)

# %% [markdown]
# ### Relationship with Categorical Variables

# %%
# For clarity the categorical_cols variable defined and showed again.
categorical_cols
# Out:
# ['Province', 'Container', 'Size_Grade']

# %%
def plot_boxplt(columns, y_name, df):
    for col in columns:
        var = col
        pred_var = y_name
        my_order = df.groupby(by=[col])[pred_var].median().sort_values().index
        data_cat = pd.concat([df[pred_var], df[var]], axis=1)
        fig, ax = plt.subplots(figsize=(8, 6))
        fig = sns.boxplot(x=var, y=pred_var, data=data_cat, order=my_order)
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
plot_boxplt(categorical_cols, "avg_price_per_kg", df_train)

# %%
# def plot_viol(columns, y_name, df):
#     for col in columns:
#         var = col
#         pred_var = y_name
#         data_cat = pd.concat([df[pred_var], df[var]], axis=1)
#         fig, ax = plt.subplots(figsize=(8, 6))
#         fig = sns.violinplot(x=var, y=pred_var, data=data_cat)
#         ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, axs = plt.subplots(3, 1, figsize = (12, 12))
fig.subplots_adjust(hspace = 0.5, wspace = 0.5)
axs = axs.ravel()

categ_columns = ["Province", "Container", "Size_Grade"]

for index, column in enumerate(categ_columns):
    axs[index].set_title("Distribution of {}".format(column), fontsize = 15)
    sns.countplot(ax = axs[index], x = column, data = df_train,  order = df_train[column].value_counts().index)
     
fig.tight_layout(pad = 1)

# %% [markdown]
# This again confrims that some of the category groups contain few observations. These can possibly be grouped together.

# %% [markdown]
# ## 4.4 Multivariate Analysis - Non-graphical
#
# The persons correlation - `df.corr()` is used to check the correlations between the columns.

# %%
df_train.drop("month", axis=1).corr()
# Out:
#                   Weight_Kg  Low_Price  High_Price  Sales_Total  \
# Weight_Kg          1.000000   0.863182    0.905852     0.180518
# Low_Price          0.863182   1.000000    0.938140     0.183230
# High_Price         0.905852   0.938140    1.000000     0.265672
# Sales_Total        0.180518   0.183230    0.265672     1.000000
# Total_Qty_Sold    -0.133317  -0.122823   -0.096456     0.771865
# Total_Kg_Sold      0.294117   0.269744    0.372282     0.962338
# Stock_On_Hand     -0.144105  -0.127677   -0.094174     0.284693
# avg_price_per_kg  -0.337886  -0.141740   -0.164496     0.108473
#
#                   Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  \
# Weight_Kg              -0.133317       0.294117      -0.144105
# Low_Price              -0.122823       0.269744      -0.127677
# High_Price             -0.096456       0.372282      -0.094174
# Sales_Total             0.771865       0.962338       0.284693
# Total_Qty_Sold          1.000000       0.651440       0.390168
# Total_Kg_Sold           0.651440       1.000000       0.229062
# Stock_On_Hand           0.390168       0.229062       1.000000
# avg_price_per_kg        0.087536      -0.001007       0.105028
#
#                   avg_price_per_kg
# Weight_Kg                -0.337886
# Low_Price                -0.141740
# High_Price               -0.164496
# Sales_Total               0.108473
# Total_Qty_Sold            0.087536
# Total_Kg_Sold            -0.001007
# Stock_On_Hand             0.105028
# avg_price_per_kg          1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

numeric_col = ["Weight_Kg", "Low_Price", "High_Price", "Sales_Total", "Total_Qty_Sold", "Total_Kg_Sold", "Stock_On_Hand"]
df = df_train[numeric_col]

X = add_constant(df)

pd.Series([variance_inflation_factor(X.values, i) 
           for i in range(X.shape[1])], 
          index=X.columns)
# Out:
# const              1.840553
# Weight_Kg          5.930872
# Low_Price          9.280307
# High_Price        14.574768
# Sales_Total       27.958520
# Total_Qty_Sold     4.085997
# Total_Kg_Sold     21.304289
# Stock_On_Hand      1.205649
# dtype: float64

# %% [markdown]
# VIF is high - drop some?

# %% [markdown]
# ## 4.5 Multivariate Analysis - Visual Representations

# %%
fig, axs = plt.subplots(figsize=(12,9))
heatmap = sns.heatmap(df_train.drop("month", axis=1).corr(), vmin=-1, vmax=1, square=True, annot=True)
heatmap.set_title("Correlation Heatmap", fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# #### say something about that there is some colinearity present - will select variables accordingly

# %% [markdown]
# #### all these plots above are in the pliots below so remove

# %%
from seaborn import pairplot
g = pairplot(df_train.drop("avg_price_per_kg", axis="columns"))
g.fig.set_size_inches(13,13)

# %% [markdown]
# # 5 More Cleaning Data

# %% [markdown]
# ## 5.1 Dummy Variable Encoding
# To transform the categorical features to numerical data that can be used in the regression models, dummy variable encoding is used. This is done with `pandas` method called `get_dummies`.

# %%
df_train.head()
# Out:
#                 Province Container Size_Grade  Weight_Kg  \
# 1                   CAPE     M4183         1L       18.3
# 7                   CAPE     JG110         2M       11.0
# 24  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 40                  CAPE     M4183         1S       18.3
# 69          EASTERN CAPE     IA400         1S      400.0
#
#                Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 1   APPLE GOLDEN DELICIOUS 2020-09-09      150.0       170.0      51710.0
# 7   APPLE GOLDEN DELICIOUS 2020-04-14       50.0        50.0      16000.0
# 24  APPLE GOLDEN DELICIOUS 2020-04-16       55.0        55.0        990.0
# 40  APPLE GOLDEN DELICIOUS 2020-05-04       80.0       120.0      32020.0
# 69  APPLE GOLDEN DELICIOUS 2020-09-28     1800.0      1800.0       1800.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg quarter  \
# 1              332         6075.6            822              8.51  2020Q3
# 7              320         3520.0              0              4.55  2020Q2
# 24              18          162.0           1506              6.11  2020Q2
# 40             388         7100.4            443              4.51  2020Q2
# 69               1          400.0              2              4.50  2020Q3
#
#    year_month  month  season
# 1     2020-09      9  spring
# 7     2020-04      4  autumn
# 24    2020-04      4  autumn
# 40    2020-05      5  autumn
# 69    2020-09      9  spring

# %%
df_train["Province"].unique()
# Out:
# array(['CAPE', 'W.CAPE-BERGRIVER ETC', 'EASTERN CAPE', 'NATAL',
#        'WEST COAST', 'TRANSVAAL', 'ORANGE FREE STATE'], dtype=object)

# %%
df_train["Container"].unique()
# Out:
# array(['M4183', 'JG110', 'JE090', 'IA400', 'EC120', 'AC030', 'M6125',
#        'EF120', 'DT063', 'M9125', 'EG140'], dtype=object)

# %%
df_train["Size_Grade"].unique()
# Out:
# array(['1L', '2M', '2S', '1S', '1M', '1X', '2L', '2U', '2X', '1U'],
#       dtype=object)

# %%
# Select columns here to create dummy variables from
dummy_columns = ["Province", "Container", "Size_Grade"]

# %%
df_dummies = pd.get_dummies(df_train, prefix="dummy", prefix_sep="_", columns=dummy_columns, drop_first=False)

# %%
# Reorder to place avg_price_per_kg in the last column
col_dum_titl = [col for col in df_dummies.columns if col != "avg_price_per_kg"] + ["avg_price_per_kg"]
df_dummies = df_dummies.reindex(columns=col_dum_titl)

# %%
# Clean dummy columns names and reorder columns
# Ensure that all the column names have underscores instead of whitespaces
df_dummies.columns = [col.replace(" ","_") for col in df_dummies.columns]

# %%
df_dummies.head()
# Out:
#     Weight_Kg             Commodities       Date  Low_Price  High_Price  \
# 1        18.3  APPLE GOLDEN DELICIOUS 2020-09-09      150.0       170.0
# 7        11.0  APPLE GOLDEN DELICIOUS 2020-04-14       50.0        50.0
# 24        9.0  APPLE GOLDEN DELICIOUS 2020-04-16       55.0        55.0
# 40       18.3  APPLE GOLDEN DELICIOUS 2020-05-04       80.0       120.0
# 69      400.0  APPLE GOLDEN DELICIOUS 2020-09-28     1800.0      1800.0
#
#     Sales_Total  Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand quarter  \
# 1       51710.0             332         6075.6            822  2020Q3
# 7       16000.0             320         3520.0              0  2020Q2
# 24        990.0              18          162.0           1506  2020Q2
# 40      32020.0             388         7100.4            443  2020Q2
# 69       1800.0               1          400.0              2  2020Q3
#
#    year_month  month  season  dummy_CAPE  dummy_EASTERN_CAPE  dummy_NATAL  \
# 1     2020-09      9  spring           1                   0            0
# 7     2020-04      4  autumn           1                   0            0
# 24    2020-04      4  autumn           0                   0            0
# 40    2020-05      5  autumn           1                   0            0
# 69    2020-09      9  spring           0                   1            0
#
#     dummy_ORANGE_FREE_STATE  dummy_TRANSVAAL  dummy_W.CAPE-BERGRIVER_ETC  \
# 1                         0                0                           0
# 7                         0                0                           0
# 24                        0                0                           1
# 40                        0                0                           0
# 69                        0                0                           0
#
#     dummy_WEST_COAST  dummy_AC030  dummy_DT063  dummy_EC120  dummy_EF120  \
# 1                  0            0            0            0            0
# 7                  0            0            0            0            0
# 24                 0            0            0            0            0
# 40                 0            0            0            0            0
# 69                 0            0            0            0            0
#
#     dummy_EG140  dummy_IA400  dummy_JE090  dummy_JG110  dummy_M4183  \
# 1             0            0            0            0            1
# 7             0            0            0            1            0
# 24            0            0            1            0            0
# 40            0            0            0            0            1
# 69            0            1            0            0            0
#
#     dummy_M6125  dummy_M9125  dummy_1L  dummy_1M  dummy_1S  dummy_1U  \
# 1             0            0         1         0         0         0
# 7             0            0         0         0         0         0
# 24            0            0         0         0         0         0
# 40            0            0         0         0         1         0
# 69            0            0         0         0         1         0
#
#     dummy_1X  dummy_2L  dummy_2M  dummy_2S  dummy_2U  dummy_2X  \
# 1          0         0         0         0         0         0
# 7          0         0         1         0         0         0
# 24         0         0         0         1         0         0
# 40         0         0         0         0         0         0
# 69         0         0         0         0         0         0
#
#     avg_price_per_kg
# 1               8.51
# 7               4.55
# 24              6.11
# 40              4.51
# 69              4.50

# %%
df_dummies.shape
# Out:
# (1952, 42)

# %%
df_dummies.columns
# Out:
# Index(['Weight_Kg', 'Commodities', 'Date', 'Low_Price', 'High_Price',
#        'Sales_Total', 'Total_Qty_Sold', 'Total_Kg_Sold', 'Stock_On_Hand',
#        'quarter', 'year_month', 'month', 'season', 'dummy_CAPE',
#        'dummy_EASTERN_CAPE', 'dummy_NATAL', 'dummy_ORANGE_FREE_STATE',
#        'dummy_TRANSVAAL', 'dummy_W.CAPE-BERGRIVER_ETC', 'dummy_WEST_COAST',
#        'dummy_AC030', 'dummy_DT063', 'dummy_EC120', 'dummy_EF120',
#        'dummy_EG140', 'dummy_IA400', 'dummy_JE090', 'dummy_JG110',
#        'dummy_M4183', 'dummy_M6125', 'dummy_M9125', 'dummy_1L', 'dummy_1M',
#        'dummy_1S', 'dummy_1U', 'dummy_1X', 'dummy_2L', 'dummy_2M', 'dummy_2S',
#        'dummy_2U', 'dummy_2X', 'avg_price_per_kg'],
#       dtype='object')

# %% [markdown]
# There are now 34 variable columns to predict our dependent variable `avg_price_per_kg`.
# <br>The coloumns that are dropped due to the `pd.get_dummies()` function parameter `drop_first = True` are:
# <br>Dropped columns = Cape, AC030, 1L

# %%
with plt.rc_context():
    plt.rc("figure", figsize=(14,10))
    plot_corr(df_dummies.corr(), xnames = df_dummies.corr().columns)

# %% [markdown]
# ??????????CHECK COLORBAR STOPS AT -0.4??

# %% [markdown]
# From the correlations there are some dummy variables that are not correlated and therefore not very usefull for the model. But there are some variables that are strongly correlated with each other wich will cause collinearity issues.

# %% [markdown]
# ## 5.2 Variable Selection
# To improve the predictive accuracy of our model we will udergo variable selection.
# <br> Doing this manually means it is discrrete, either keep or discard

# %% [markdown]
# also known as subset selection - if you select only some of all th e rpedictor variables

# %% [markdown]
# OR should you continue as per the train for variable selction and check correlation, multicolinearity, and only keep those certain entries? or as per the test on some threshold for unique values?

# %% [markdown]
# ### Variable Selection by Correlation
# ???

# %% [markdown]
# select which are most important
# <br> hypothesis testing
# <br>lower propability the more significant
# <br>significance threshold
# <br>correlation

# %% [markdown]
# create table dataframe and > 0/9

# %% [markdown]
# For this analysis, we can determine the relationship between any two numerical features by calculating the correlation coefficient. Correlation is a measure of the degree to which two variables change together, if at all. If two features have a strong positive correlation, it means that if the value of one feature increases, the value of the other feature also increases. There are three different correlation measures:
#
#     - Pearson correlation
#     - Spearman rank correlation
#     - Kendall correlation
#
# For this lesson, we will focus on the Pearson correlation. The Pearson correlation measures the linear relationship between features and assumes that the features are normally distributed. Below is a table that explains how to interpret the Pearson correlation measure:

# %% [markdown]
# ### Variable Selection by Significance
# ??? how far are values form mean
# <br>
# low variance features contain less info
# <br>Scale!!
# <br>get rid of variables that dont contribute much
# <br>use minmaxscaler and land variancethreshold

# %% [markdown]
# ## 5.3 Scaling

# %% [markdown]
# ### Standardisation

# %% [markdown]
# Z-score standardisation - for similar ranges - fairly robust to outliers

# %% [markdown]
# we want the magnitutdes of the coefficients to be dependent on the strength of the relantionship between the rpedictor variables and the output variable - not becuase of difference in measured units

# %% [markdown]
# Have different ranges - units vary - different scales - box and whisker plots on similiar ranges

# %% [markdown]
# not sensitive to outliers

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_standardise = pd.DataFrame(X_scaled, columns=X.columns)

# %% [markdown]
# ### Normalisation

# %% [markdown]
# squeez beteen [0.1] and rest are decimals in between

# %% [markdown]
# sensitive to outliers!

# %% [markdown]
# # 6. Revisit EDA

# %%
df_train.head()
# Out:
#                 Province Container Size_Grade  Weight_Kg  \
# 1                   CAPE     M4183         1L       18.3
# 7                   CAPE     JG110         2M       11.0
# 24  W.CAPE-BERGRIVER ETC     JE090         2S        9.0
# 40                  CAPE     M4183         1S       18.3
# 69          EASTERN CAPE     IA400         1S      400.0
#
#                Commodities       Date  Low_Price  High_Price  Sales_Total  \
# 1   APPLE GOLDEN DELICIOUS 2020-09-09      150.0       170.0      51710.0
# 7   APPLE GOLDEN DELICIOUS 2020-04-14       50.0        50.0      16000.0
# 24  APPLE GOLDEN DELICIOUS 2020-04-16       55.0        55.0        990.0
# 40  APPLE GOLDEN DELICIOUS 2020-05-04       80.0       120.0      32020.0
# 69  APPLE GOLDEN DELICIOUS 2020-09-28     1800.0      1800.0       1800.0
#
#     Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg quarter  \
# 1              332         6075.6            822              8.51  2020Q3
# 7              320         3520.0              0              4.55  2020Q2
# 24              18          162.0           1506              6.11  2020Q2
# 40             388         7100.4            443              4.51  2020Q2
# 69               1          400.0              2              4.50  2020Q3
#
#    year_month  month  season
# 1     2020-09      9  spring
# 7     2020-04      4  autumn
# 24    2020-04      4  autumn
# 40    2020-05      5  autumn
# 69    2020-09      9  spring

# %% [markdown]
# ## 6.1 Province Variable

# %%
plt.figure(figsize=(15,8))
c = sns.swarmplot(x="Province", y="avg_price_per_kg", data=df_train, size = 3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
def group_cat(df, column, categories):
    '''
    Joins the list of categories in the column to a single category to reduce the number of categories.
    '''
    df = df.copy()
    df[column] = df[column].apply(lambda x: "_".join(categories) if x in categories else x)
    return df

# %%
def use_mode(df, column, categories):
    '''
    Replaces the list of categories in the column with the mode category to reduce the number of categories.
    '''
    df = df.copy()
    mode = df[column].mode()[0]
    df[column] = df[column].apply(lambda x: mode if x in categories else x)
    return df

# %%
test = use_mode(df_train, "Province", ["TRANSVAAL", "ORANGE FREE STATE"])

# %%
test['Province'].value_counts()
# Out:
# CAPE                    1069
# W.CAPE-BERGRIVER ETC     440
# EASTERN CAPE             206
# WEST COAST               126
# NATAL                    111
# Name: Province, dtype: int64

# %%
df_train['Province'].value_counts()
# Out:
# CAPE                    1045
# W.CAPE-BERGRIVER ETC     440
# EASTERN CAPE             206
# WEST COAST               126
# NATAL                    111
# TRANSVAAL                 15
# ORANGE FREE STATE          9
# Name: Province, dtype: int64

# %%
plt.figure(figsize=(15,8))
c = sns.swarmplot(x="Province", y="avg_price_per_kg", data=test, size=3)

# %% [markdown]
# ## Container Variable

# %%
plt.figure(figsize=(15,8))
c = sns.swarmplot(x="Container", y="avg_price_per_kg", data=df_train, size=3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
test = use_mode(test, 'Container', ['M9125', 'EG140', 'DT063', 'M6125', 'AC030'])

# %%
test["Container"].value_counts()
# Out:
# M4183    641
# JE090    565
# EC120    448
# IA400    139
# JG110     85
# EF120     74
# Name: Container, dtype: int64

# %%
df_train["Container"].value_counts()
# Out:
# M4183    588
# JE090    565
# EC120    448
# IA400    139
# JG110     85
# EF120     74
# AC030     31
# M6125     10
# DT063      6
# M9125      3
# EG140      3
# Name: Container, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(x="Container", y="avg_price_per_kg", data=test, size=3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Container', ylabel='avg_price_per_kg'>

# %% [markdown]
# ## 6.3 Size_Grade Variable

# %%
plt.figure(figsize=(15,8))
c = sns.swarmplot(x="Size_Grade", y="avg_price_per_kg", data=test, size=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-7144a17f84f8> in <module>
#       1 plt.figure(figsize=(15,8))
# ----> 2 sns.swarmplot(x="Size_Grade", y="avg_price_per_kg", data=test, size=3)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2999         warnings.warn(msg, UserWarning)
#    3000
# -> 3001     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
#    3002                             dodge, orient, color, palette)
#    3003     if ax is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, dodge, orient, color, palette)
#    1170                  dodge, orient, color, palette):
#    1171         """Initialize the plotter."""
# -> 1172         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1173         self.establish_colors(color, palette, 1)
#    1174
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Size_Grade'

# %%
def split_sizegrade(df, column):
    df = df.copy()
    df["grade"] = df[column].apply(lambda x: "A" if "1" in x else "B")
    def get_size(v):
        if "l" in v.lower():
            return "L"
        if "m" in v.lower():
            return "M"
        if "s" in v.lower():
            return "S"
        if "x" in v.lower():
            return "X"
        return "U"
    df["size"] = df[column].apply(get_size)
    df = df.drop(column, axis=1)
    return df

# %%
test = split_sizegrade(test, "Size_Grade")

# %%
plt.figure(figsize=(15,8))
c = sns.swarmplot(x="size", y="avg_price_per_kg", data=test, size=3, order=["U", "S", "M", "L", "X"])

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(x="grade", y="avg_price_per_kg", data=test, size=3)

# %% [markdown]
# ## 6.4 Weight_Kg Variable

# %%
plt.figure(figsize=(15,8))
sns.swarmplot(x="Weight_Kg", y="avg_price_per_kg", data=test, size=3)
# Out:
# C:\Users\leon1\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\leon1\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\leon1\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
def num_to_cat_thres(df, column, thres):
    df = df.copy()
    df[column] = df[column].apply(lambda x: f"{column}_low" if x > thres else f"{column}_high")
    return df

# %%
test = num_to_cat_thres(df_train, 'Weight_Kg', 200)

# %%
sns.scatterplot(x="Low_Price", y="avg_price_per_kg", data=test, hue='Weight_Kg')

# %%
sns.scatterplot(x="High_Price", y="avg_price_per_kg", data=test, hue='Weight_Kg')

# %%
df_train["Weight_Kg"].unique()
# Out:
# array([ 18.3,  11. ,   9. , 400. ,  12. ,   3. ,  12.5,   6.3,  14. ])

# %%
def num_to_cat(df, column):
    df = df.copy()
    df[column] = df[column].astype(str)
    df[column] = df[column].apply(lambda x: f"{column}_{x}")
    return df

# %%
test = num_to_cat(df_train, 'Weight_Kg')

# %%
sns.scatterplot(x="Low_Price", y="avg_price_per_kg", data=test, hue='Weight_Kg')

# %%
sns.scatterplot(x="High_Price", y="avg_price_per_kg", data=test, hue='Weight_Kg')

# %% [markdown]
# # Outliers

# %% [markdown]
# From Kurtosis the following numeric variables have outliers:<br>
# - Weight_Kg
# - Low_Price
# - High_Price
# - Sales_Total
# - Total_Qty_Sold
# - Total_Kg_Sold
# - Stock_On_Hand

# %% [markdown]
# How to deal with outliers? Check on graphs and logical reasoning and then removove them or other method?

# %%
sns.displot(df_train['avg_price_per_kg'])

# %%
df_train[df_train["avg_price_per_kg"] > 15]
# Out:
#       Province Container Size_Grade  Weight_Kg             Commodities  \
# 1228      CAPE     M4183         1L       18.3  APPLE GOLDEN DELICIOUS
# 56010     CAPE     M4183         1X       18.3  APPLE GOLDEN DELICIOUS
#
#             Date  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 1228  2020-08-24      140.0       180.0      15160.0              39
# 56010 2020-01-24      280.0       280.0       1680.0               6
#
#        Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg quarter year_month  \
# 1228           713.7            736             21.24  2020Q3    2020-08
# 56010          109.8             36             15.30  2020Q1    2020-01
#
#        month  season
# 1228       8  winter
# 56010      1  summer

# %% [markdown]
# ## Change the outliers

# %%
def change_outlier(df, column, thres):
    df = df.copy()
    df[column] = df[column].apply(lambda x: thres if x > thres else x)
    return df

# %%
test = change_outlier(df_train, 'avg_price_per_kg', 15)

# %%
sns.displot(test['avg_price_per_kg'])

# %% [markdown]
# ### Or drop the outliers

# %%
def drop_outlier(df, column, thres):
    df = df.copy()
    df = df[df[column] < thres]
    return df

# %%
test = drop_outlier(df_train, "avg_price_per_kg", 15)

# %%
sns.displot(test['avg_price_per_kg'])

# %% [markdown]
# # 5.4 Processing Functions

# %% [markdown]
# To make the process reproduceable and easy to follow, all the cleaning steps are coded into functions.

# %% [markdown]
# #### Read data again to make sure processing is repeatable.

# %%
df_train = pd.read_csv("data/df - train_set.csv")
df_test = pd.read_csv("data/df - test_set.csv", index_col=0)

# %%
df_train.head()
# Out:
#             Province Container Size_Grade  Weight_Kg             Commodities  \
# 0               CAPE     EC120         1L       12.0      APPLE GRANNY SMITH
# 1               CAPE     M4183         1L       18.3  APPLE GOLDEN DELICIOUS
# 2            GAUTENG     AT200         1L       20.0       AVOCADO PINKERTON
# 3          TRANSVAAL     BJ090         1L        9.0      TOMATOES-LONG LIFE
# 4  WESTERN FREESTATE     PP100         1R       10.0   POTATO SIFRA (WASHED)
#
#          Date  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 0  2020-03-10      108.0       112.0       3236.0              29
# 1  2020-09-09      150.0       170.0      51710.0             332
# 2  2020-05-05       70.0        80.0       4860.0              66
# 3  2020-01-20       60.0        60.0        600.0              10
# 4  2020-07-14       40.0        45.0      41530.0             927
#
#    Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg
# 0          348.0              0              9.30
# 1         6075.6            822              8.51
# 2         1320.0             50              3.68
# 3           90.0              0              6.67
# 4         9270.0            393              4.48

# %%
def keep_golden(df):
    '''
    Filter the dataframe on the Commodities column to only keep
    the APPLE GOLDEN DELICIOUS category.
    '''
    df = df.copy()
    df = df[df['Commodities'] == 'APPLE GOLDEN DELICIOUS']
    df = df.drop(['Commodities'], axis=1)
    return df

# %%
df = keep_golden(df_train)

# %%
df.shape
# Out:
# (1952, 12)

# %%
def dtype_to_datetime(df, column):
    df = df.copy()
    df[column] = pd.to_datetime(df[column])
    return df

# %%
df = dtype_to_datetime(df, 'Date')

# %%
def split_date(df, date_col):
    df['day_of_week'] = df[date_col].dt.day_name()
    df['month'] = df[date_col].dt.month_name()
    df['year_month'] = pd.PeriodIndex(df[date_col], freq='M').astype(str)
    df['quarter'] = pd.PeriodIndex(df[date_col], freq='Q').astype(str)
    df['season'] = df["month"].apply(lambda x: get_season(x))
    df = df.drop(['Date'], axis=1)
    return df

# %%
df = split_date(df, 'Date')

# %%
def dummy(df, columns):
    df = pd.get_dummies(df, prefix='dummy', prefix_sep='_', columns=columns, drop_first=True)
    return df

# %%
df = split_sizegrade(df, "Size_Grade")

# %%
df.head()
# Out:
#                 Province Container  Weight_Kg  Low_Price  High_Price  \
# 1                   CAPE     M4183       18.3      150.0       170.0
# 7                   CAPE     JG110       11.0       50.0        50.0
# 24  W.CAPE-BERGRIVER ETC     JE090        9.0       55.0        55.0
# 40                  CAPE     M4183       18.3       80.0       120.0
# 69          EASTERN CAPE     IA400      400.0     1800.0      1800.0
#
#     Sales_Total  Total_Qty_Sold  Total_Kg_Sold  Stock_On_Hand  \
# 1       51710.0             332         6075.6            822
# 7       16000.0             320         3520.0              0
# 24        990.0              18          162.0           1506
# 40      32020.0             388         7100.4            443
# 69       1800.0               1          400.0              2
#
#     avg_price_per_kg day_of_week      month year_month quarter  season grade  \
# 1               8.51   Wednesday  September    2020-09  2020Q3  spring     A
# 7               4.55     Tuesday      April    2020-04  2020Q2  spring     B
# 24              6.11    Thursday      April    2020-04  2020Q2  spring     B
# 40              4.51      Monday        May    2020-05  2020Q2  spring     A
# 69              4.50      Monday  September    2020-09  2020Q3  spring     A
#
#    size
# 1     L
# 7     M
# 24    S
# 40    S
# 69    S

# %%
df = dummy(df, ['Province','Container','grade', 'size', 'month', 'day_of_week', 'year_month', 'quarter', 'season'])

# %%
X = df.drop(['avg_price_per_kg'], axis=1)

# %%
X.head()
# Out:
#     Weight_Kg  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 1        18.3      150.0       170.0      51710.0             332
# 7        11.0       50.0        50.0      16000.0             320
# 24        9.0       55.0        55.0        990.0              18
# 40       18.3       80.0       120.0      32020.0             388
# 69      400.0     1800.0      1800.0       1800.0               1
#
#     Total_Kg_Sold  Stock_On_Hand  dummy_EASTERN CAPE  dummy_NATAL  \
# 1          6075.6            822                   0            0
# 7          3520.0              0                   0            0
# 24          162.0           1506                   0            0
# 40         7100.4            443                   0            0
# 69          400.0              2                   1            0
#
#     dummy_ORANGE FREE STATE  dummy_TRANSVAAL  dummy_W.CAPE-BERGRIVER ETC  \
# 1                         0                0                           0
# 7                         0                0                           0
# 24                        0                0                           1
# 40                        0                0                           0
# 69                        0                0                           0
#
#     dummy_WEST COAST  dummy_DT063  dummy_EC120  dummy_EF120  dummy_EG140  \
# 1                  0            0            0            0            0
# 7                  0            0            0            0            0
# 24                 0            0            0            0            0
# 40                 0            0            0            0            0
# 69                 0            0            0            0            0
#
#     dummy_IA400  dummy_JE090  dummy_JG110  dummy_M4183  dummy_M6125  \
# 1             0            0            0            1            0
# 7             0            0            1            0            0
# 24            0            1            0            0            0
# 40            0            0            0            1            0
# 69            1            0            0            0            0
#
#     dummy_M9125  dummy_B  dummy_M  dummy_S  dummy_U  dummy_X  dummy_August  \
# 1             0        0        0        0        0        0             0
# 7             0        1        1        0        0        0             0
# 24            0        1        0        1        0        0             0
# 40            0        0        0        1        0        0             0
# 69            0        0        0        1        0        0             0
#
#     dummy_December  dummy_February  dummy_January  dummy_July  dummy_June  \
# 1                0               0              0           0           0
# 7                0               0              0           0           0
# 24               0               0              0           0           0
# 40               0               0              0           0           0
# 69               0               0              0           0           0
#
#     dummy_March  dummy_May  dummy_October  dummy_September  dummy_Monday  \
# 1             0          0              0                1             0
# 7             0          0              0                0             0
# 24            0          0              0                0             0
# 40            0          1              0                0             1
# 69            0          0              0                1             1
#
#     dummy_Saturday  dummy_Thursday  dummy_Tuesday  dummy_Wednesday  \
# 1                0               0              0                1
# 7                0               0              1                0
# 24               0               1              0                0
# 40               0               0              0                0
# 69               0               0              0                0
#
#     dummy_2020-01  dummy_2020-02  dummy_2020-03  dummy_2020-04  dummy_2020-05  \
# 1               0              0              0              0              0
# 7               0              0              0              1              0
# 24              0              0              0              1              0
# 40              0              0              0              0              1
# 69              0              0              0              0              0
#
#     dummy_2020-06  dummy_2020-07  dummy_2020-08  dummy_2020-09  dummy_2020-10  \
# 1               0              0              0              1              0
# 7               0              0              0              0              0
# 24              0              0              0              0              0
# 40              0              0              0              0              0
# 69              0              0              0              1              0
#
#     dummy_2020Q1  dummy_2020Q2  dummy_2020Q3  dummy_2020Q4
# 1              0             0             1             0
# 7              0             1             0             0
# 24             0             1             0             0
# 40             0             1             0             0
# 69             0             0             1             0

# %%
def scaling(X):
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    X_standardise = pd.DataFrame(X_scaled, columns=X.columns)
    return X_standardise

# %%
new = scaling(X)

# %%
new.head()
# Out:
#    Weight_Kg  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 0  -0.222433  -0.065087   -0.105317     0.811807        0.510117
# 1  -0.295704  -0.332855   -0.382175    -0.103950        0.471248
# 2  -0.315779  -0.319467   -0.370639    -0.488870       -0.506948
# 3  -0.222433  -0.252525   -0.220674     0.306871        0.691504
# 4   3.608756   4.353082    3.655338    -0.468098       -0.562012
#
#    Total_Kg_Sold  Stock_On_Hand  dummy_EASTERN CAPE  dummy_NATAL  \
# 0       0.511073       0.571070           -0.343488    -0.245547
# 1       0.091837      -0.563874           -0.343488    -0.245547
# 2      -0.459029       1.515476           -0.343488    -0.245547
# 3       0.679187       0.047781           -0.343488    -0.245547
# 4      -0.419986      -0.561112            2.911310    -0.245547
#
#    dummy_ORANGE FREE STATE  dummy_TRANSVAAL  dummy_W.CAPE-BERGRIVER ETC  \
# 0                -0.068059           -0.088                   -0.539449
# 1                -0.068059           -0.088                   -0.539449
# 2                -0.068059           -0.088                    1.853743
# 3                -0.068059           -0.088                   -0.539449
# 4                -0.068059           -0.088                   -0.539449
#
#    dummy_WEST COAST  dummy_DT063  dummy_EC120  dummy_EF120  dummy_EG140  \
# 0         -0.262685    -0.055527    -0.545777    -0.198503    -0.039233
# 1         -0.262685    -0.055527    -0.545777    -0.198503    -0.039233
# 2         -0.262685    -0.055527    -0.545777    -0.198503    -0.039233
# 3         -0.262685    -0.055527    -0.545777    -0.198503    -0.039233
# 4         -0.262685    -0.055527    -0.545777    -0.198503    -0.039233
#
#    dummy_IA400  dummy_JE090  dummy_JG110  dummy_M4183  dummy_M6125  \
# 0    -0.276891    -0.638243    -0.213372     1.523065    -0.071759
# 1    -0.276891    -0.638243     4.686652    -0.656571    -0.071759
# 2    -0.276891     1.566802    -0.213372    -0.656571    -0.071759
# 3    -0.276891    -0.638243    -0.213372     1.523065    -0.071759
# 4     3.611532    -0.638243    -0.213372    -0.656571    -0.071759
#
#    dummy_M9125   dummy_B   dummy_M   dummy_S   dummy_U   dummy_X  \
# 0    -0.039233 -0.750233 -0.627129 -0.869135 -0.099143 -0.335038
# 1    -0.039233  1.332918  1.594569 -0.869135 -0.099143 -0.335038
# 2    -0.039233  1.332918 -0.627129  1.150569 -0.099143 -0.335038
# 3    -0.039233 -0.750233 -0.627129  1.150569 -0.099143 -0.335038
# 4    -0.039233 -0.750233 -0.627129  1.150569 -0.099143 -0.335038
#
#    dummy_August  dummy_December  dummy_February  dummy_January  dummy_July  \
# 0     -0.377964       -0.181119       -0.295745      -0.270402   -0.537074
# 1     -0.377964       -0.181119       -0.295745      -0.270402   -0.537074
# 2     -0.377964       -0.181119       -0.295745      -0.270402   -0.537074
# 3     -0.377964       -0.181119       -0.295745      -0.270402   -0.537074
# 4     -0.377964       -0.181119       -0.295745      -0.270402   -0.537074
#
#    dummy_June  dummy_March  dummy_May  dummy_October  dummy_September  \
# 0   -0.284327    -0.378849  -0.292661      -0.124935         3.625593
# 1   -0.284327    -0.378849  -0.292661      -0.124935        -0.275817
# 2   -0.284327    -0.378849  -0.292661      -0.124935        -0.275817
# 3   -0.284327    -0.378849   3.416917      -0.124935        -0.275817
# 4   -0.284327    -0.378849  -0.292661      -0.124935         3.625593
#
#    dummy_Monday  dummy_Saturday  dummy_Thursday  dummy_Tuesday  \
# 0     -0.480384       -0.332194       -0.498879      -0.483613
# 1     -0.480384       -0.332194       -0.498879       2.067771
# 2     -0.480384       -0.332194        2.004494      -0.483613
# 3      2.081666       -0.332194       -0.498879      -0.483613
# 4      2.081666       -0.332194       -0.498879      -0.483613
#
#    dummy_Wednesday  dummy_2020-01  dummy_2020-02  dummy_2020-03  \
# 0         1.875771      -0.270402      -0.295745      -0.378849
# 1        -0.533114      -0.270402      -0.295745      -0.378849
# 2        -0.533114      -0.270402      -0.295745      -0.378849
# 3        -0.533114      -0.270402      -0.295745      -0.378849
# 4        -0.533114      -0.270402      -0.295745      -0.378849
#
#    dummy_2020-04  dummy_2020-05  dummy_2020-06  dummy_2020-07  dummy_2020-08  \
# 0      -0.343488      -0.292661      -0.284327      -0.537074      -0.377964
# 1       2.911310      -0.292661      -0.284327      -0.537074      -0.377964
# 2       2.911310      -0.292661      -0.284327      -0.537074      -0.377964
# 3      -0.343488       3.416917      -0.284327      -0.537074      -0.377964
# 4      -0.343488      -0.292661      -0.284327      -0.537074      -0.377964
#
#    dummy_2020-09  dummy_2020-10  dummy_2020Q1  dummy_2020Q2  dummy_2020Q3  \
# 0       3.625593      -0.124935     -0.614458     -0.591550      1.176178
# 1      -0.275817      -0.124935     -0.614458      1.690476     -0.850212
# 2      -0.275817      -0.124935     -0.614458      1.690476     -0.850212
# 3      -0.275817      -0.124935     -0.614458      1.690476     -0.850212
# 4       3.625593      -0.124935     -0.614458     -0.591550      1.176178
#
#    dummy_2020Q4
# 0     -0.124935
# 1     -0.124935
# 2     -0.124935
# 3     -0.124935
# 4     -0.124935

# %%
new.shape
# Out:
# (1952, 57)

# %% [markdown]
# # 5. Modelling

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv("data/df - train_set.csv")
df_test = pd.read_csv("data/df - test_set.csv", index_col=0)

# %%
df_train.head()
# Out:
#             Province Container Size_Grade  Weight_Kg             Commodities  \
# 0               CAPE     EC120         1L       12.0      APPLE GRANNY SMITH
# 1               CAPE     M4183         1L       18.3  APPLE GOLDEN DELICIOUS
# 2            GAUTENG     AT200         1L       20.0       AVOCADO PINKERTON
# 3          TRANSVAAL     BJ090         1L        9.0      TOMATOES-LONG LIFE
# 4  WESTERN FREESTATE     PP100         1R       10.0   POTATO SIFRA (WASHED)
#
#          Date  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 0  2020-03-10      108.0       112.0       3236.0              29
# 1  2020-09-09      150.0       170.0      51710.0             332
# 2  2020-05-05       70.0        80.0       4860.0              66
# 3  2020-01-20       60.0        60.0        600.0              10
# 4  2020-07-14       40.0        45.0      41530.0             927
#
#    Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg
# 0          348.0              0              9.30
# 1         6075.6            822              8.51
# 2         1320.0             50              3.68
# 3           90.0              0              6.67
# 4         9270.0            393              4.48

# %%
categorical_cols = ['Province', 'Container', 'Size_Grade']
numerical_cols = ['Weight_Kg', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold', 'Total_Kg_Sold', 'Stock_On_Hand']
date_cols = ['Date']
label = ['avg_price_per_kg']

# %% [markdown]
# ## 5.1 Model 1: Linear Regression Basic

# %% [markdown]
# This is the benchmark model which only contains numerical column variables.

# %%
df_train.columns
# Out:
# Index(['Province', 'Container', 'Size_Grade', 'Weight_Kg', 'Commodities',
#        'Date', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold',
#        'Total_Kg_Sold', 'Stock_On_Hand', 'avg_price_per_kg'],
#       dtype='object')

# %%
# processing
df = keep_golden(df_train)
X = df[numerical_cols]
y = df['avg_price_per_kg']

# %%
model = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 1.8029960581006492

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 1.7190231085203476

# %% [markdown]
# ### Look at Trained Model

# %%
beta_0 = float(model.intercept_)

# %%
model.coef_
# Out:
# array([-1.99772076e-02,  4.72358619e-04,  3.02309603e-03,  1.14375520e-04,
#        -3.45483276e-03, -5.82917078e-04,  9.83894927e-05])

# %%
X.columns
# Out:
# Index(['Weight_Kg', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold',
#        'Total_Kg_Sold', 'Stock_On_Hand'],
#       dtype='object')

# %%
beta_js = pd.DataFrame(model.coef_, X.columns, columns = ["Coefficient"])

# %%
print("Intercept:\t", beta_0)
print("\n", beta_js)
# Out:
# Intercept:	 6.82992620420897
#
#                  Coefficient
# Weight_Kg         -0.019977
# Low_Price          0.000472
# High_Price         0.003023
# Sales_Total        0.000114
# Total_Qty_Sold    -0.003455
# Total_Kg_Sold     -0.000583
# Stock_On_Hand      0.000098

# %%
def pred_vs_act(y_test,y_test_pred):
    # Create figure and axes
    f, ax = plt.subplots(figsize=(5,5))

    # Plot on axes
    ax.set_title('Predicted vs Actual')
    ax.set_xlabel('Actual')
    ax.set_ylabel('Predicted')
    ax.scatter(y_test,y_test_pred)
    ax.plot(y_test,y_test,'r')
    plt.show()

# %%
pred_vs_act(y_test, y_test_pred)

# %% [markdown]
# ?????If cant find plots check in train 11

# %%
errors = np.array(df.Y - y_gen)
np.round(errors, 2)
plt.hist(errors)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-695-0a4b39da6084> in <module>
# ----> 1 errors = np.array(df.Y - y_gen)
#       2 np.round(errors, 2)
#       3 plt.hist(errors)
#       4 plt.show()
#
# C:\Users\leon1\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Y'

# %% [markdown]
# In addition to having some very large errors, we can also see that most of the errors are positive numbers. Ideally, we want our errors to be evenly distributed either side of zero - we want our line to best fit the data, i.e. no bias.
#
# We can measure the overall error of the fit by calculating the **Residual Sum of Squares**:
#
# $$RSS = \sum_{i=1}^n(y_i-\hat{y}_i)^2$$
#
# The RSS finds the difference between the y-value of each data point and our estimated line (which may be either negative or positive), squares the difference, and then adds all the differences up. In other words, it's the sum of the squares of all the errors we calculated before.

# %%
print("Residual sum of squares:", (errors ** 2).sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-696-74ebb58ca56a> in <module>
# ----> 1 print("Residual sum of squares:", (errors ** 2).sum())
#
# NameError: name 'errors' is not defined

# %% [markdown]
# Here we can see our RSS has improved from ~867 down to ~321.
# Furthermore, if we calculate the sum of the errors we find that the value is close to 0.

# %% [markdown]
# ### First Kaggle submission

# %%
# subm preprocessing
df = keep_golden(df_test)
X = df[numerical_cols]

# %%
model_submit_results = model.predict(X)

# %%
df_submit = df_test.reset_index()[['Index']]
df_submit['avg_price_per_kg'] = model_submit_results

# %%
from datetime import datetime
now = datetime.now().strftime('%Y%m%d%H%M')
df_submit.to_csv(f'submissions/ae1_leon_{now}.csv', index=False)

# %% [markdown]
# ### Kaggle Score

# %% [markdown]
# Benchmark results got an RMSE of 1.66952.
# Now on to trying to improve test/train split RMSE with:
# - categorical data
# - manual feature selection
# - regularization models

# %% [markdown]
# ## 5.2 Model 2: Linear Regression with Categorical

# %% [markdown]
# Now using categorical dat also.

# %%
df = keep_golden(df_train)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = dummy(df, ['Province','Container','Size_Grade', 'month', 'day_of_week', 'year_month', 'quarter', 'season'])
y = df[['avg_price_per_kg']]
X = df.drop('avg_price_per_kg', axis=1)
X = scaling(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 1.3248592360733324

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 1.3416440865628296

# %%
pred_vs_act(y_test, y_test_pred)

# %% [markdown]
# Using the categorical columns improves the score.

# %% [markdown]
# ## More processing

# %%
# df[["Total_Qty_Sold","Stock_On_Hand"]] = np.log(df[["Total_Qty_Sold","Stock_On_Hand"]]).fillna(0).replace(-np.inf, 0).replace(np.inf, 0)

# %%
df = keep_golden(df_train)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
df = drop_outlier(df, "avg_price_per_kg", 15)
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
y = df[['avg_price_per_kg']]
X = df.drop('avg_price_per_kg', axis=1)
X = scaling(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 1.3215253331421988

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 1.325197244209664

# %%
pred_vs_act(y_test, y_test_pred)

# %% [markdown]
# ### Second Kaggle submission

# %%
# subm preprocessing
df = keep_golden(df_test)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
X = scaling(df)

# %%
model_submit_results = model.predict(X)

# %%
df_submit = df_test.reset_index()[['Index']]
df_submit['avg_price_per_kg'] = model_submit_results

# %%
from datetime import datetime
now = datetime.now().strftime('%Y%m%d%H%M')
df_submit.to_csv(f'submissions/ae1_leon_{now}.csv', index=False)

# %% [markdown]
# ### Kaggle Score

# %% [markdown]
# Benchmark results got an RMSE of 1.66952.
# Now on to trying to improve test/train split RMSE with:
# - categorical data
# - manual feature selection
# - regularization models

# %% [markdown]
# ## 5.3 Model 3: Linear Regression Manual Feature Selection

# %%
# select based on multicolinearity
manual_features_selected = ['Province', 'Container', 'Size_Grade', 'Weight_Kg',
       'Date', 'Low_Price', 'Sales_Total', 'Stock_On_Hand']

# %% [markdown]
# ## 5.2 Model 2: Ridge

# %% [markdown]
# Because we standardised the features, we can compare coefficients to each other, since their respective variables are all on the same scale. We can interpret the intercepts as the expected average price per kg when all the features are equal to their respective means and the coefficients are interpreted as the expected change in average price per kg given an increase of 1 in the scaled feature value.

# %% [markdown]
# can now be constrained to continuos value - all are inmcluded

# %% [markdown]
# do one for non regularised lin model and regularised one and compare train 17

# %% [markdown]
# minimise RSS = improve overall fit of model - now penalise individ coeff that get too large - those that contiruibute the most to reducing the fit

# %% [markdown]
# trade off = training fit vs size of coeffs

# %% [markdown]
# Penalty terms - the alpha - reduce shrink the coefficients values to zero

# %%
df = keep_golden(df_train)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
df = drop_outlier(df, "avg_price_per_kg", 15)
df.head()
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
y = df[['avg_price_per_kg']]
X = df.drop('avg_price_per_kg', axis=1)
X = scaling(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model = Ridge(alpha=10)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 1.3286281380276717

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 1.3169383463976225

# %%
def get_feature_importances(model, X):
    feature_importance = pd.DataFrame()
    feature_importance['feature'] = X.columns
    try:
        feature_importance['coef'] = model.coef_[0]
    except:
        feature_importance['coef'] = model.feature_importances_
    feature_importance = feature_importance.sort_values('coef', ascending=False)
    return feature_importance

# %%
get_feature_importances(model, X)
# Out:
#                        feature      coef
# 2                  Sales_Total  1.850639
# 1                   High_Price  0.708936
# 22        dummy_Weight_Kg_12.0  0.243808
# 10  dummy_W.CAPE-BERGRIVER ETC  0.195800
# 13                 dummy_EC120  0.188351
# 14                 dummy_EF120  0.150282
# 0                    Low_Price  0.129248
# 25        dummy_Weight_Kg_18.3  0.117391
# 19                 dummy_M4183  0.117391
# 38                     dummy_X  0.087415
# 29         dummy_Weight_Kg_9.0  0.055370
# 17                 dummy_JE090  0.055370
# 20                 dummy_M6125  0.036316
# 15                 dummy_EG140  0.024135
# 24        dummy_Weight_Kg_14.0  0.024135
# 23        dummy_Weight_Kg_12.5  0.022787
# 28         dummy_Weight_Kg_6.3  0.016594
# 12                 dummy_DT063  0.016594
# 21                 dummy_M9125 -0.018873
# 35                     dummy_M -0.047880
# 26         dummy_Weight_Kg_3.0 -0.057894
# 18                 dummy_JG110 -0.064004
# 5                Stock_On_Hand -0.064984
# 8      dummy_ORANGE FREE STATE -0.068442
# 11            dummy_WEST COAST -0.069539
# 9              dummy_TRANSVAAL -0.076148
# 33                dummy_2020Q4 -0.090496
# 37                     dummy_U -0.100146
# 36                     dummy_S -0.292184
# 6           dummy_EASTERN CAPE -0.424796
# 3               Total_Qty_Sold -0.455475
# 7                  dummy_NATAL -0.468223
# 30                dummy_2020Q1 -0.472240
# 34                     dummy_B -0.499233
# 32                dummy_2020Q3 -0.612484
# 27       dummy_Weight_Kg_400.0 -0.661874
# 16                 dummy_IA400 -0.661874
# 31                dummy_2020Q2 -0.760183
# 4                Total_Kg_Sold -1.476643

# %% [markdown]
# ### Third Kaggle submission

# %%
# subm preprocessing
df = keep_golden(df_test)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
X = scaling(df)

# %%
model_submit_results = model.predict(X)

# %%
df_submit = df_test.reset_index()[['Index']]
df_submit['avg_price_per_kg'] = model_submit_results

# %%
from datetime import datetime
now = datetime.now().strftime('%Y%m%d%H%M')
df_submit.to_csv(f'submissions/ae1_leon_{now}.csv', index=False)

# %% [markdown]
# ### Kaggle Score

# %% [markdown]
# Benchmark results got an RMSE of 1.66952.
# Now on to trying to improve test/train split RMSE with:
# - categorical data
# - manual feature selection
# - regularization models

# %% [markdown]
# ## 5.2 Model 2: Lasso

# %%
df = keep_golden(df_train)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
df = drop_outlier(df, "avg_price_per_kg", 15)
df.head()
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
y = df[['avg_price_per_kg']]
X = df.drop('avg_price_per_kg', axis=1)
# X = scaling(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model = Lasso()

# %%
model.fit(X_train, y_train)
# Out:
# Lasso()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 1.920636292361781

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 2.0141912374695203

# %% [markdown]
# ## 5.2 Model 2: Random Forest

# %%
df = keep_golden(df_train)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
df = drop_outlier(df, "avg_price_per_kg", 15)
df.head()
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
y = df[['avg_price_per_kg']]
X = df.drop('avg_price_per_kg', axis=1)
X = scaling(X)

# %%
model = RandomForestRegressor(max_depth=6, min_samples_split=5, min_samples_leaf=3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\leon1\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(max_depth=6, min_samples_leaf=3, min_samples_split=5)

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_rmse = (metrics.mean_squared_error(y_train, y_train_pred))**0.5
train_rmse
# Out:
# 0.5719890443901366

# %%
test_rmse = (metrics.mean_squared_error(y_test, y_test_pred))**0.5
test_rmse
# Out:
# 0.6463925085084834

# %% [markdown]
# ### Fourth Kaggle submission

# %%
# subm preprocessing
df = keep_golden(df_test)
df = dtype_to_datetime(df, 'Date')
df = split_date(df, 'Date')
df = df.drop(['day_of_week', 'month', 'year_month', 'season'], axis=1)
df = split_sizegrade(df, 'Size_Grade')
df = num_to_cat(df, 'Weight_Kg')
# df = dummy(df, df.select_dtypes(include=['object']).columns)
df = dummy(df, ["Province", "Container", "Weight_Kg", "quarter", "grade", "size"])
X = scaling(df)

# %%
model_submit_results = model.predict(X)

# %%
df_submit = df_test.reset_index()[['Index']]
df_submit['avg_price_per_kg'] = model_submit_results

# %%
from datetime import datetime
now = datetime.now().strftime('%Y%m%d%H%M')
df_submit.to_csv(f'submissions/ae1_leon_{now}.csv', index=False)

# %% [markdown]
# ### Kaggle Score

# %% [markdown]
# Benchmark results got an RMSE of 1.66952.
# Now on to trying to improve test/train split RMSE with:
# - categorical data
# - manual feature selection
# - regularization models

# %% [markdown]
# #### A few plots showing residuals and true data vs line etc.

# %% [markdown]
# # 6. Results for Submission / Deploy Model

# %% [markdown]
# # 7. Conclusion

# %% [markdown]
# # 8. References
